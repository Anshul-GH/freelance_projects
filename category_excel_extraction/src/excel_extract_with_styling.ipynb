# %%
# import xlrd
import openpyxl

# %%
source_data = '../data/sample.xlsx'

# %%
book = openpyxl.load_workbook(source_data)
sheet = book.active

# %%
for val in sheet.iter_rows():
    print(val)
# Out:
# (<Cell 'Sheet1'.A1>, <Cell 'Sheet1'.B1>)
# (<Cell 'Sheet1'.A2>, <Cell 'Sheet1'.B2>)
# (<Cell 'Sheet1'.A3>, <Cell 'Sheet1'.B3>)
# (<Cell 'Sheet1'.A4>, <Cell 'Sheet1'.B4>)
# (<Cell 'Sheet1'.A5>, <Cell 'Sheet1'.B5>)

# %%
# cell_ = sheet.cell(row=5, column=2)
cell_ = sheet.cell(row=3, column=2)
cell_.font
# Out:
# <openpyxl.styles.fonts.Font object>
# Parameters:
# name='Calibri', charset=None, family=2.0, b=True, i=False, strike=None, outline=None, shadow=None, condense=None, color=<openpyxl.styles.colors.Color object>
# Parameters:
# rgb=None, indexed=None, auto=None, theme=1, tint=0.0, type='theme', extend=None, sz=11.0, u=None, vertAlign=None, scheme='minor'

# %%
sheet = book.sheet_by_index(0)

# %%
for record in range(sheet.nrows):
    print(sheet.row(record))
# Out:
# [xldate:41213.0, empty:'', empty:'', empty:'', empty:'', empty:'', empty:'', empty:'', empty:'', empty:'', empty:'', empty:'', empty:'', empty:'']
# [text:'Vendor name', text:'Point of Contact for TEKsystems', text:'Vendor POC Phone number', text:'Vendor POC Email address', text:'Street Address', text:'City ', text:'State', text:'Zip Code', text:'Minority Vendor', text:'skill set 1', text:'skill set 2', text:'skill set 3', text:'skill set 4', text:'skill set 5']
# [text:'22nd Century Technologies Inc', text:'Tim ', text:'732.507.7968', text:'tim@tscti.com', text:'2 Executive Drive', text:'Somerset', text:'New Jersey', text:'08873', text:'yes', text:'IT Infrastructure', text:'.Net', text:'Java', text:'Unix', text:'Enterprise Architect']
# ...
